# %%
#5-20
A=[]
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,1))
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,0))
A.append((0,0,1))

# %%
#22-50
B=[]
B.append((0,0,0))
B.append((0,0,0))
B.append((0,1,1))
B.append((0,0,0))
B.append((0,0,0))
B.append((0,0,0))
B.append((0,0,0))
B.append((0,0,0))
B.append((0,0,0))
B.append((0,0,0))
B.append((0,1,1))
B.append((0,0,2))
B.append((0,0,5))
B.append((0,0,0))
B.append((0,0,0))

#55-100
C=[]
C.append((0,0,2))
C.append((0,1,1))
C.append((1,3,3))
C.append((1,1,1))
C.append((8,8,8))
C.append((0,1,1))
C.append((7,7,7))
C.append((0,0,11))
C.append((2,2,2))
C.append((6,6,6))


X=[]
for i in range(5,21):
    X.append(i)
for i in range(22,51,2):
    X.append(i)
for i in range(55,101,5):
    X.append(i)

Y=A+B+C

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 5))
plt.plot(X,Y)
plt.show()

# %%
#100-1000
D=[]
D.append((6,6,6,100))
D.append((35,29,76,200))
D.append((9,9,35,300))
D.append((36,59,88,400))
D.append((84,85,425,500))
D.append((24,24,58,600))
D.append((26,26,109,700))
D.append((130,274,809,800))
D.append((56,56,56,900))
D.append((203,203,506,1000))
E=[]
for i in range(1,11):
    E.append(i*100)
plt.figure(figsize=(20, 10))
plt.plot(E,D)
plt.show()
